# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

import csv

# %%
driver=webdriver.Chrome()

# %%
# Click on View more Stories Button

driver.get(url="https://www.hindustantimes.com/topic/g20-summit")

try:
    driver.switch_to.alert.text
    driver.switch_to.alert.accept()
    driver.switch_to.alert.dismiss()
except Exception as e:
    print("No Alert Present")

more =driver.find_elements(By.XPATH,'//*[@id="dataHolder"]/div[9]/a')
print(more)    
more[0].click()
# Out:
# No Alert Present
# [<selenium.webdriver.remote.webelement.WebElement (session="6d470769c282d222f5baf24c2b4ec80d", element="8A250BDEB033F166E08F60FAC666E789_element_36")>]

# %%
# check for notification pop up

try:
    notification_button=driver.find_element(By.XPATH,'/html/body/div/div[2]/div[2]/button[1]')
    print(notification_button)
    notification_button[0].click()
except Exception as b:
    print("No Notification pop up detected.")
# Out:
# No Notification pop up detected.

# %%
j=0
articles_dict={}
divNo=4
for j in range(40):
    j= j+1
    try:    
        articles=driver.find_element(By.XPATH, f'/html/body/section[1]/section/section/div[{divNo}]/h3/a')
        div_link = articles.get_attribute("href")
        
        details = {
        'id': j,
        'publisher': 'Hinduatan Times',
        'title': articles.text,
        'link': div_link,
        'publish_details':'',
        'content':""
        }
        articles_dict[f'{j}']=details
    except Exception as e:
        pass
    
    divNo=divNo+1
print(articles_dict)
# Out:
# {'1': {'id': 1, 'publisher': 'Hinduatan Times', 'title': 'Virtual G20 Summit to be held on November 22', 'link': 'https://www.hindustantimes.com/india-news/virtual-g20-summit-to-be-held-on-november-22-101700312938577.html', 'publish_details': '', 'content': ''}, '2': {'id': 2, 'publisher': 'Hinduatan Times', 'title': 'Biden links Hamas attack with West Asia reset push', 'link': 'https://www.hindustantimes.com/india-news/biden-links-hamas-attack-with-west-asia-reset-push-101698343749987.html', 'publish_details': '', 'content': ''}, '3': {'id': 3, 'publisher': 'Hinduatan Times', 'title': 'G20 Summit ‘bridged deep divides’, says Jaishankar', 'link': 'https://www.hindustantimes.com/india-news/g20-summit-bridged-deep-divides-says-jaishankar-101698074976769.html', 'publish_details': '', 'content': ''}, '6': {'id': 6, 'publisher': 'Hinduatan Times', 'title': 'India writing new saga of progress: Modi', 'link': 'https://www.hindustantimes.com/india-news/india-writing-new-saga-of-progress-modi-101697795398469.html', 'publish_details': '', 'content': ''}, '7': {'id': 7, 'publisher': 'Hinduatan Times', 'title': 'Climate lessons from G20 for Dubai COP28', 'link': 'https://www.hindustantimes.com/opinion/climate-lessons-from-g20-for-dubai-cop28-101697465764227.html', 'publish_details': '', 'content': ''}, '8': {'id': 8, 'publisher': 'Hinduatan Times', 'title': "'PM Modi's policies focussed around people': Singapore speaker", 'link': 'https://www.hindustantimes.com/india-news/pm-modis-policies-focussed-around-people-singapore-speaker-101697289226152.html', 'publish_details': '', 'content': ''}, '10': {'id': 10, 'publisher': 'Hinduatan Times', 'title': "PM Modi's 'time to move together' message as he inaugurates 9th P20 Summit", 'link': 'https://www.hindustantimes.com/india-news/pm-modi-p20-g20-summit-new-delhi-101697176882841.html', 'publish_details': '', 'content': ''}, '11': {'id': 11, 'publisher': 'Hinduatan Times', 'title': 'ITPO announces rules, tariff for hosting events at Delhi’s Bharat Mandapam', 'link': 'https://www.hindustantimes.com/cities/delhi-news/itpo-announces-rules-tariff-for-hosting-events-at-delhi-s-bharat-mandapam-101697046390392.html', 'publish_details': '', 'content': ''}, '12': {'id': 12, 'publisher': 'Hinduatan Times', 'title': 'Indian lessons for consensus building', 'link': 'https://www.hindustantimes.com/opinion/indian-lessons-for-consensus-building-101696944528556.html', 'publish_details': '', 'content': ''}, '14': {'id': 14, 'publisher': 'Hinduatan Times', 'title': 'An African century, facilitated by India', 'link': 'https://www.hindustantimes.com/opinion/an-african-century-facilitated-by-india-101696513601613.html', 'publish_details': '', 'content': ''}, '15': {'id': 15, 'publisher': 'Hinduatan Times', 'title': 'Tackling the dragon on land and at sea', 'link': 'https://www.hindustantimes.com/opinion/tackling-the-dragon-on-land-and-at-sea-101696321944089.html', 'publish_details': '', 'content': ''}, '16': {'id': 16, 'publisher': 'Hinduatan Times', 'title': 'Accomplished 4 significant tasks in three months: Shah lauds PM Modi', 'link': 'https://www.hindustantimes.com/india-news/accomplished-4-significant-tasks-in-three-months-shah-lauds-pm-modi-101696100461045.html', 'publish_details': '', 'content': ''}, '18': {'id': 18, 'publisher': 'Hinduatan Times', 'title': 'Tasks of 50 years accomplished in 3 years under PM Modi: Amit Shah', 'link': 'https://www.hindustantimes.com/cities/others/tasks-of-50-years-accomplished-in-3-years-under-pm-modi-amit-shah-101696087735423.html', 'publish_details': '', 'content': ''}, '19': {'id': 19, 'publisher': 'Hinduatan Times', 'title': 'G20, space mission, women’s Bill gave India new energy: Shah', 'link': 'https://www.hindustantimes.com/india-news/g20-space-mission-women-s-bill-gave-india-new-energy-shah-101696013748851.html', 'publish_details': '', 'content': ''}, '20': {'id': 20, 'publisher': 'Hinduatan Times', 'title': 'Part of Manipur problem due to migrants: S Jaishankar', 'link ...

# %%
for keys in articles_dict.keys():
    link=articles_dict[keys]['link']
    driver.get(url=link)
    
    date=driver.find_element(By.XPATH,"/html/body/section[1]/section/div[3]/div/div[2]/div[1]").text
    content= driver.find_element(By.XPATH,'/html/body/section[1]/section/div[3]/div').text
    
    articles_dict[keys]['publish_details']= date
    articles_dict[keys]['content']= content

# %%
print(articles_dict)
# Out:
# {'1': {'id': 1, 'publisher': 'Hinduatan Times', 'title': 'Virtual G20 Summit to be held on November 22', 'link': 'https://www.hindustantimes.com/india-news/virtual-g20-summit-to-be-held-on-november-22-101700312938577.html', 'publish_details': 'Nov 18, 2023 06:38 PM IST', 'content': "Virtual G20 Summit to be held on November 22\nBy\nHT Correspondent\nNov 18, 2023 06:38 PM IST\nDuring the closing session of the G20 Summit in New Delhi on September 10, Prime Minister Narendra Modi had announced that India will host a virtual summit prior before the conclusion of India’s presidency at the end of November\nThe virtual G20 Summit to be hosted by India on November 22 will push for effective implementation of various G20 decisions and review developments since the holding of the in-person summit of the world’s largest economies in September.\nIndia holds the G20 presidency until November 30. (File Photo)\nDuring the closing session of the G20 Summit in New Delhi on September 10, Prime Minister Narendra Modi had announced that India will host a virtual summit prior before the conclusion of India’s presidency at the end of November. The virtual virtual summit will be chaired by Modi.\nWe're now on WhatsApp. Click to join.\nLeaders of all G20 members, including the chair of the African Union, heads of state and government of nine guest countries, and heads of 11 international organisations, have been invited to the virtual meet, the external affairs ministry said on Saturday.\nIt was not immediately clear whether China will participate in the virtual meeting, and at what level. President Xi Jinping had skipped the G20 Summit in September.\nReferring to the unanimous adoption of the G20 New Delhi Leaders’ Declaration at the in-person summit in September, the external affairs ministry said the virtual meeting will “take forward key, select outcomes [and] action points” from the summit and “review developments since then”.\n“The virtual G20 Summit is also expected to push for effective implementation of various G20 decisions, including through relevant national and international platforms,” the ministry said.\nThe deliberations of the second Voice of Global South Summit, held on Friday, will feed into the discussions at the virtual summit.\nPeople familiar with the matter said the Israel-Hamas conflict and the Ukraine war are expected to figure at the virtual summit. Unlike the in-person summit in September, an outcome document such as a leaders’ declaration is not expected at the virtual summit.\nIndia holds the G20 presidency until November 30. The G20 troika during the Brazil’s G20 presidency in 2024 will comprise India, Brazil and South Africa.\nGet Latest India News along with Latest News and Top Headlines from India and around the world\nTOPICS\nG20 Summit"}, '2': {'id': 2, 'publisher': 'Hinduatan Times', 'title': 'Biden links Hamas attack with West Asia reset push', 'link': 'https://www.hindustantimes.com/india-news/biden-links-hamas-attack-with-west-asia-reset-push-101698343749987.html', 'publish_details': 'Oct 27, 2023 05:32 AM IST', 'content': "Biden links Hamas attack with West Asia reset push\nBy\nPrashant Jha\n, Washington\nOct 27, 2023 05:32 AM IST\nUS President Joe Biden links Hamas's attack on Israel to regional integration efforts in West Asia, mentioning the establishment of diplomatic ties between Saudi Arabia-Israel and the India-Middle East-Europe Economic Corridor (IMEC). He also emphasizes the US's competition with China, highlighting the IMEC as a challenge to China's Belt & Road Initiative. Biden reaffirms commitment to the Quad and expresses anticipation for the Quad Leaders' Summit in India. He discusses the need for a better future in the region, integrating Israel while considering the aspirations of the Palestinian people.\nUS President Joe Biden has drawn a direct link between Hamas’s terror attack against Israel with the US-led efforts at regional integration in West Asia, hinting at the process to establish  ...

# %%
# Flatten the nested structure
flat_articles_list = []
for article_id, article_data in articles_dict.items():
    flat_article = {'id': article_data['id'], 'publisher': article_data['publisher'], 'title': article_data['title'], 'link': article_data['link'], 'publish_details': article_data['publish_details'], 'content': article_data['content']}
    flat_articles_list.append(flat_article)

# Specify the CSV file path
csv_file_path = 'Hindustan_Times.csv'

# Write the flattened data to a CSV file
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['id', 'publisher', 'title', 'link', 'publish_details', 'content']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    # Write the header
    writer.writeheader()
    
    # Write the data
    writer.writerows(flat_articles_list)

print(f"The data has been written to '{csv_file_path}'.")
# Out:
# The data has been written to 'Hindustan_Times.csv'.
